# %% [markdown]
# # Creación de tablas de bias e intensity para cada noticia

# %%
import sys
sys.path.insert(0, '../frameaxis')
from semaxis import CoreUtil
from semaxis import SemAxis
import pandas as pd
import logging

# %%
logging.basicConfig(level=logging.INFO,
                    format='%(asctime)s %(name)-12s %(levelname)-8s %(message)s',
                    datefmt="%Y-%m-%d %H:%M:%S")
logger = logging.getLogger(__name__)
logger.setLevel(logging.INFO)

# %%
EMBEDDINGS_PATH = "embeddings/embeddings-l-model.vec" # ../data/embeddings/glove.840B.300d.w2vformat.txt
AXES_PATH = "axes/antonimos_combinados.tsv"
VERSION = "V3"

# %% [markdown]
# Comenzamos leyendo el dataset de noticias

# %%
news_df = pd.read_csv("dataset/news_sample_with_summaries.csv")

# %%
news_df.head()
# Out:
#           uri                                              title  \
# 0  7147072310  La Florida pide al Gobierno y al SII que autop...
# 1  7263576433  4 de cada 10 departamentos arrendados en centr...
# 2  7124645893  Rehabilitación en casa: Teletón implementa pla...
# 3  6955202611  Brote covid entre trabajadores obliga a suspen...
# 4  7135704010  Dólar cae de los $900 de la mano de la depreci...
#
#                                                 body       outlet  \
# 0  El alcalde de La Florida, Rodolfo Carter, soli...  BioBioChile
# 1  Un estudio realizado por la Cámara Chilena de ...  BioBioChile
# 2  Una plataforma de telerrehabilitación creada p...  BioBioChile
# 3  3 han sido los establecimientos que presentaro...  BioBioChile
# 4  El tipo de cambio está en el soporte clave de ...  BioBioChile
#
#                                              summary  \
# 0  El alcalde de La Florida, Rodolfo Carter, ha s...
# 1  Un estudio de la Cámara Chilena de la Construc...
# 2  Una startup chilena, Trainfes, lanzará una pla...
# 3  Tres establecimientos en la región de Los Lago...
# 4  El tipo de cambio del dólar se encuentra en un...
#
#                                       summary_claude  \
# 0   \n\nEl alcalde de La Florida, Rodolfo Carter,...
# 1   \n\nUn estudio de la Cámara Chilena de la Con...
# 2   \n\nUna startup chilena ha creado una platafo...
# 3   \n\nTres establecimientos de la región de Los...
# 4   \n\nEl tipo de cambio del dólar se encuentra ...
#
#                                       summary_gemini
# 0  El alcalde de La Florida, Rodolfo Carter, exig...
# 1  Un estudio de la Cámara Chilena de la Construc...
# 2  Una startup chilena implementará este año en l...
# 3  En la región de Los Lagos, tres establecimient...
# 4  El tipo de cambio del dólar en Chile se encuen...

# %% [markdown]
# Inicializamos el modelo con el embedding y el diccionario de antónimos (o ejes)

# %%
frameaxis = SemAxis(CoreUtil.load_embedding(EMBEDDINGS_PATH, is_binary=False), axes_str=CoreUtil.load_axes_file(AXES_PATH))
# Out:
# 2025-06-20 19:10:30 gensim.models.keyedvectors INFO     loading projection weights from embeddings/embeddings-l-model.vec
# 2025-06-20 19:33:06 gensim.utils INFO     KeyedVectors lifecycle event {'msg': 'loaded (1313423, 300) matrix of type float32 from embeddings/embeddings-l-model.vec', 'binary': False, 'encoding': 'utf8', 'datetime': '2025-06-20T19:33:06.599776', 'gensim': '4.1.2', 'python': '3.8.0 (tags/v3.8.0:fa919fd, Oct 14 2019, 19:37:50) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.26100-SP0', 'event': 'load_word2vec_format'}
# 2025-06-20 19:33:06 semaxis      ERROR    ('a cuatro aguas', 'a dos aguas') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis\semaxis.py", line 29, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis\core.py", line 19, in map_axis_to_vec
#     return (emb[axis[1]] - emb[axis[0]])
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 395, in __getitem__
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# KeyError: "Key 'a dos aguas' not present"
# 2025-06-20 19:33:06 semaxis      ERROR    ('a favor del aborto', 'en contra del aborto') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis\semaxis.py", line 29, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis\core.py", line 19, in map_axis_to_vec
#     return (emb[axis[1]] - emb[axis[0]])
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 395, in __getitem__
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# KeyError: "Key 'en contra del aborto' not present"
# 2025-06-20 19:33:06 semaxis      ERROR    ('a flote', 'encallado') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis\semaxis.py", line 29, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis\core.py", line 19, in map_axis_to_vec
#     return (emb[axis[1]] - emb[axis[0]])
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 395, in __getitem__
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# KeyError: "Key 'a flote' not present"
# 2025-06-20 19:33:06 semaxis      ERROR    ('a la carta', 'menú del día') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis\semaxis.py", line 29, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis\core.py", line 19, in map_axis_to_vec
#     return (emb[axis[1]] - emb[axis[0]])
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 395, in __getitem__
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# KeyError: "Key 'menú del día' not present"
# 2025-06-20 19:33:06 semaxis      ERROR    ('a lo largo', 'de lado') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis\semaxis.py", line 29, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis\core.py", line 19, in map_axis_to_vec
#     return (emb[axis[1]] - emb[axis[0]])
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 395, in __getitem__
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# KeyError: "Key 'de lado' not present"
# 2025-06-20 19:33:06 semaxis      ERROR    ('a posteriori', 'a priori') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis\semaxis.py", line 29, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis\core.py", line 19, in map_axis_to_vec
#     return (emb[axis[1]] - emb[axis[0]])
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 395, in __getitem__
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# KeyError: "Key 'a priori' not present"
# 2025-06-20 19:33:06 semaxis      ERROR    ('a término', 'prematuro') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis\semaxis.py", line 29, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis\core.py", line 19, in map_axis_to_vec
#     return (emb[axis[1]] - emb[axis[0]])
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 395, in __getitem__
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# KeyError: "Key 'a término' not present"
# 2025-06-20 19:33:06 semaxis      ERROR    ('abactinal', 'actinal') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis\semaxis.py", line 29, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis\core.py", line 19, in map_axis_to_vec
#     return (emb[axis[1]] - emb[axis[0]])
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 395, in __getitem__
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# KeyError: "Key 'actinal' not present"
# 2025-06-20 19:33:06 semaxis      ERROR    ('abducente', 'aducente') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis\semaxis.py", line 29, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis\core.py", line 19, in map_axis_to_vec
#     return (emb[axis[1]] - emb[axis[0]])
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 395, in __getitem__
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# KeyError: "Key 'aducente' not present"
# 2025-06-20 19:33:06 semaxis      ERROR    ('abranquial', 'branquial') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis\semaxis.py", line 29, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis\core.py", line 19, in map_axis_to_vec
#     return (emb[axis[1]] - emb[axis[0]])
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 395, in __getitem__
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# KeyError: "Key 'abranquial' not present"
# 2025-06-20 19:33:06 semaxis      ERROR    ('abreviado', 'no abreviado') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis\semaxis.py", line 29, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis\core.py", line 19, in map_axis_to_vec
#     return (emb[axis[1]] - emb[axis[0]])
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 395, in __getitem__
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# KeyError: "Key 'no abreviado' not present"
# 2025-06-20 19:33:06 semaxis      ERROR    ('absorbente', 'no absorbente') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis\semaxis.py", line 29, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis\core.py", line 19, in map_axis_to_vec
#     return (emb[axis[1]] - emb[axis[0]])
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 395, in __getitem__
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# KeyError: "Key 'no absorbente' not present"
# 2025-06-20 19:33:06 semaxis      ERROR    ('absorbible', 'adsorbible') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis\semaxis.py", line 29, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis\core.py", line 19, in map_axis_to_vec
#     return (emb[axis[1]] - emb[axis[0]])
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 395, in __getitem__
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# KeyError: "Key 'adsorbible' not present"
# 2025-06-20 19:33:06 semaxis      ERROR    ('abusado', 'no abusado') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis\semaxis.py", line 29, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis\core.py", line 19, in map_axis_to_vec
#     return (emb[axis[1]] - emb[axis[0]])
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 395, in __getitem__
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# KeyError: "Key 'no abusado' not present"
# 2025-06-20 19:33:06 semaxis      ERROR    ('académico', 'no académico') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis\semaxis.py", line 29, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis\core.py", line 19, in map_axis_to_vec
#     return (emb[axis[1]] - emb[axis[0]])
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 395, in __getitem__
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# KeyError: "Key 'no académico' not present"
# 2025-06-20 19:33:06 semaxis      ERROR    ('acarpeloso', 'carpeloide') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis\semaxis.py", line 29, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis\core.py", line 19, in map_axis_to_vec
#     return (emb[axis[1]] - emb[axis[0]])
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 395, in __getitem__
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# KeyError: "Key 'carpeloide' not present"
# 2025-06-20 19:33:06 semaxis      ERROR    ('acataléctico', 'caléctico') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis\semaxis.py", line 29, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis\core.py", line 19, in map_axis_to_vec
#     return (emb[axis[1]] - emb[axis[0]])
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 395, in __getitem__
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# KeyError: "Key 'caléctico' not present"
# 2025-06-20 19:33:06 semaxis      ERROR    ('acataléctico', 'hipercataléctico') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis\semaxis.py", line 29, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis\core.py", line 19, in map_axis_to_vec
#     return (emb[axis[1]] - emb[axis[0]])
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 395, in __getitem__
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# KeyError: "Key 'hipercataléctico' not present"
# 2025-06-20 19:33:06 semaxis      ERROR    ('acaudalado', 'sin dinero') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis\semaxis.py", line 29, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis\core.py", line 19, in map_axis_to_vec
#     return (emb[axis[1]] - emb[axis[0]])
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 395, in __getitem__
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# KeyError: "Key 'sin dinero' not present"
# 2025-06-20 19:33:06 semaxis      ERROR    ('acaulento', 'caulento') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis\semaxis.py", line 29, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis\core.py", line 19, in map_axis_to_vec
#     return (emb[axis[1]] - emb[axis[0]])
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 395, in __getitem__
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# KeyError: "Key 'caulento' not present"
# 2025-06-20 19:33:06 semaxis      ERROR    ('accesivo', 'desapegado') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis\semaxis.py", line 29, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis\core.py", line 19, in map_axis_to_vec
#     return (emb[axis[1]] - emb[axis[0]])
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 395, in __getitem__
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# KeyError: "Key 'accesivo' not present"
# 2025-06-20 19:33:06 semaxis      ERROR    ('acertado', 'inigual') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis\semaxis.py", line 29, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis\core.py", line 19, in map_axis_to_vec
#     return (emb[axis[1]] - emb[axis[0]])
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 395, in __getitem__
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# KeyError: "Key 'inigual' not present"
# 2025-06-20 19:33:06 semaxis      ERROR    ('aclamídeo', 'clámídeo') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis\semaxis.py", line 29, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis\core.py", line 19, in map_axis_to_vec
#     return (emb[axis[1]] - emb[axis[0]])
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 395, in __getitem__
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# KeyError: "Key 'clámídeo' not present"
# 2025-06-20 19:33:06 semaxis      ERROR    ('acogedor', 'poco acogedor') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis\semaxis.py", line 29, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis\core.py", line 19, in map_axis_to_vec
#     return (emb[axis[1]] - emb[axis[0]])
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 395, in __getitem__
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# KeyError: "Key 'poco acogedor' not present"
# 2025-06-20 19:33:06 semaxis      ERROR    ('acomodador', 'poco dispuesto') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis\semaxis.py", line 29, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis\core.py", line 19, in map_axis_to_vec
#     return (emb[axis[1]] - emb[axis[0]])
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 395, in __getitem__
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# KeyError: "Key 'poco dispuesto' not present"
# 2025-06-20 19:33:06 semaxis      ERROR    ('acompañado', 'no acompañado') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis\semaxis.py", line 29, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis\core.py", line 19, in map_axis_to_vec
#     return (emb[axis[1]] - emb[axis[0]])
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 395, in __getitem__
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# KeyError: "Key 'no acompañado' not present"
# 2025-06-20 19:33:06 semaxis      ERROR    ('acondrítico', 'condrítico') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis\semaxis.py", line 29, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis\core.py", line 19, in map_axis_to_vec
#     return (emb[axis[1]] - emb[axis[0]])
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 395, in __getitem__
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# KeyError: "Key 'acondrítico' not present"
# 2025-06-20 19:33:06 semaxis      ERROR    ('acordante', 'discordante') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis\semaxis.py", line 29, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis\core.py", line 19, in map_axis_to_vec
#     return (emb[axis[1]] - emb[axis[0]])
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 395, in __getitem__
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# KeyError: "Key 'acordante' not present"
# 2025-06-20 19:33:06 semaxis      ERROR    ('acostumbrado', 'no acostumbrado') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis\semaxis.py", line 29, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis\core.py", line 19, in map_axis_to_vec
#     return (emb[axis[1]] - emb[axis[0]])
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 395, in __getitem__
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# KeyError: "Key 'no acostumbrado' not present"
# 2025-06-20 19:33:06 semaxis      ERROR    ('acrocárpico', 'pleurocárpico') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis\semaxis.py", line 29, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis\core.py", line 19, in map_axis_to_vec
#     return (emb[axis[1]] - emb[axis[0]])
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 395, in __getitem__
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# KeyError: "Key 'pleurocárpico' not present"
# 2025-06-20 19:33:06 semaxis      ERROR    ('acropetal', 'basipetal') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis\semaxis.py", line 29, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis\core.py", line 19, in map_axis_to_vec
#     return (emb[axis[1]] - emb[axis[0]])
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 395, in __getitem__
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# KeyError: "Key 'basipetal' not present"
# 2025-06-20 19:33:06 semaxis      ERROR    ('actuable', 'inactuable') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis\semaxis.py", line 29, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis\core.py", line 19, in map_axis_to_vec
#     return (emb[axis[1]] - emb[axis[0]])
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 395, in __getitem__
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# KeyError: "Key 'inactuable' not present"
# 2025-06-20 19:33:06 semaxis      ERROR    ('adaptable', 'no adaptable') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis\semaxis.py", line 29, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis\core.py", line 19, in map_axis_to_vec
#     return (emb[axis[1]] - emb[axis[0]])
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 395, in __getitem__
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# KeyError: "Key 'no adaptable' not present"
# 2025-06-20 19:33:06 semaxis      ERROR    ('adecuada', 'inigual') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis\semaxis.py", line 29, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis\core.py", line 19, in map_axis_to_vec
#     return (emb[axis[1]] - emb[axis[0]])
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 395, in __getitem__
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# KeyError: "Key 'inigual' not present"
# 2025-06-20 19:33:06 semaxis      ERROR    ('adecuado', 'inigual') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis\semaxis.py", line 29, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis\core.py", line 19, in map_axis_to_vec
#     return (emb[axis[1]] - emb[axis[0]])
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 395, in __getitem__
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# KeyError: "Key 'inigual' not present"
# 2025-06-20 19:33:06 semaxis      ERROR    ('adherido', 'no adherido') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis\semaxis.py", line 29, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis\core.py", line 19, in map_axis_to_vec
#     return (emb[axis[1]] - emb[axis[0]])
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 395, in __getitem__
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# KeyError: "Key 'no adherido' not present"
# 2025-06-20 19:33:06 semaxis      ERROR    ('adhesivo', 'no adhesivo') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis\semaxis.py", line 29, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis\core.py", line 19, in map_axis_to_vec
#     return (emb[axis[1]] - emb[axis[0]])
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 395, in __getitem__
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# KeyError: "Key 'no adhesivo' not present"
# 2025-06-20 19:33:06 semaxis      ERROR    ('adiabático', 'diabático') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis\semaxis.py", line 29, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis\core.py", line 19, in map_axis_to_vec
#     return (emb[axis[1]] - emb[axis[0]])
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 395, in __getitem__
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# KeyError: "Key 'diabático' not present"
# 2025-06-20 19:33:06 semaxis      ERROR    ('adictivo', 'no adictivo') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis\semaxis.py", line 29, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis\core.py", line 19, in map_axis_to_vec
#     return (emb[axis[1]] - emb[axis[0]])
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 395, in __getitem__
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# KeyError: "Key 'no adictivo' not present"
# 2025-06-20 19:33:06 semaxis      ERROR    ('adicto', 'no adicto') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis\semaxis.py", line 29, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis\core.py", line 19, in map_axis_to_vec
#     return (emb[axis[1]] - emb[axis[0]])
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 395, in __getitem__
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# KeyError: "Key 'no adicto' not present"
# 2025-06-20 19:33:06 semaxis      ERROR    ('adjunto', 'desajuntado') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis\semaxis.py", line 29, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis\core.py", line 19, in map_axis_to_vec
#     return (emb[axis[1]] - emb[axis[0]])
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 395, in __getitem__
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# KeyError: "Key 'desajuntado' not present"
# 2025-06-20 19:33:06 semaxis      ERROR    ('adoptable', 'no adoptable') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis\semaxis.py", line 29, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis\core.py", line 19, in map_axis_to_vec
#     return (emb[axis[1]] - emb[axis[0]])
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 395, in __getitem__
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# KeyError: "Key 'no adoptable' not present"
# 2025-06-20 19:33:06 semaxis      ERROR    ('adornado', 'desprovisto de adornos') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis\semaxis.py", line 29, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis\core.py", line 19, in map_axis_to_vec
#     return (emb[axis[1]] - emb[axis[0]])
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 395, in __getitem__
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# KeyError: "Key 'desprovisto de adornos' not present"
# 2025-06-20 19:33:06 semaxis      ERROR    ('adsorbente', 'no adsorbente') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis\semaxis.py", line 29, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis\core.py", line 19, in map_axis_to_vec
#     return (emb[axis[1]] - emb[axis[0]])
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 395, in __getitem__
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# KeyError: "Key 'no adsorbente' not present"
# 2025-06-20 19:33:06 semaxis      ERROR    ('afectado', 'no afectado') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis\semaxis.py", line 29, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis\core.py", line 19, in map_axis_to_vec
#     return (emb[axis[1]] - emb[axis[0]])
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 395, in __getitem__
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# KeyError: "Key 'no afectado' not present"
# 2025-06-20 19:33:06 semaxis      ERROR    ('afeitado', 'no afeitado') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis\semaxis.py", line 29, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis\core.py", line 19, in map_axis_to_vec
#     return (emb[axis[1]] - emb[axis[0]])
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 395, in __getitem__
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# ...
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# KeyError: "Key 'sin sangre' not present"
# 2025-06-20 19:33:10 semaxis      ERROR    ('sellado', 'sin sellar') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis\semaxis.py", line 29, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis\core.py", line 19, in map_axis_to_vec
#     return (emb[axis[1]] - emb[axis[0]])
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 395, in __getitem__
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# KeyError: "Key 'sin sellar' not present"
# 2025-06-20 19:33:10 semaxis      ERROR    ('sin agallas', 'valiente') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis\semaxis.py", line 29, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis\core.py", line 19, in map_axis_to_vec
#     return (emb[axis[1]] - emb[axis[0]])
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 395, in __getitem__
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# KeyError: "Key 'sin agallas' not present"
# 2025-06-20 19:33:10 semaxis      ERROR    ('sin tacto', 'táctico') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis\semaxis.py", line 29, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis\core.py", line 19, in map_axis_to_vec
#     return (emb[axis[1]] - emb[axis[0]])
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 395, in __getitem__
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# KeyError: "Key 'sin tacto' not present"
# 2025-06-20 19:33:10 semaxis      ERROR    ('sin tallar', 'tallado') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis\semaxis.py", line 29, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis\core.py", line 19, in map_axis_to_vec
#     return (emb[axis[1]] - emb[axis[0]])
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 395, in __getitem__
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# KeyError: "Key 'sin tallar' not present"
# 2025-06-20 19:33:10 semaxis      ERROR    ('sin tamaño', 'tamaño') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis\semaxis.py", line 29, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis\core.py", line 19, in map_axis_to_vec
#     return (emb[axis[1]] - emb[axis[0]])
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 395, in __getitem__
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# KeyError: "Key 'sin tamaño' not present"
# 2025-06-20 19:33:10 semaxis      ERROR    ('sin tapa', 'tapa') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis\semaxis.py", line 29, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis\core.py", line 19, in map_axis_to_vec
#     return (emb[axis[1]] - emb[axis[0]])
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 395, in __getitem__
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# KeyError: "Key 'sin tapa' not present"
# 2025-06-20 19:33:10 semaxis      ERROR    ('sin templar', 'templado') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis\semaxis.py", line 29, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis\core.py", line 19, in map_axis_to_vec
#     return (emb[axis[1]] - emb[axis[0]])
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 395, in __getitem__
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# KeyError: "Key 'sin templar' not present"
# 2025-06-20 19:33:10 semaxis      ERROR    ('sin tierra', 'terroso') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis\semaxis.py", line 29, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis\core.py", line 19, in map_axis_to_vec
#     return (emb[axis[1]] - emb[axis[0]])
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 395, in __getitem__
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# KeyError: "Key 'sin tierra' not present"
# 2025-06-20 19:33:10 semaxis      ERROR    ('sin ventilación', 'ventilado') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis\semaxis.py", line 29, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis\core.py", line 19, in map_axis_to_vec
#     return (emb[axis[1]] - emb[axis[0]])
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 395, in __getitem__
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# KeyError: "Key 'sin ventilación' not present"
# 2025-06-20 19:33:10 semaxis      ERROR    ('sin vidriar', 'vidriado') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis\semaxis.py", line 29, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis\core.py", line 19, in map_axis_to_vec
#     return (emb[axis[1]] - emb[axis[0]])
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 395, in __getitem__
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# KeyError: "Key 'sin vidriar' not present"
# 2025-06-20 19:33:10 semaxis      ERROR    ('sobrecabeza', 'superficie') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis\semaxis.py", line 29, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis\core.py", line 19, in map_axis_to_vec
#     return (emb[axis[1]] - emb[axis[0]])
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 395, in __getitem__
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# KeyError: "Key 'sobrecabeza' not present"
# 2025-06-20 19:33:10 semaxis      ERROR    ('subscrito', 'superescrito') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis\semaxis.py", line 29, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis\core.py", line 19, in map_axis_to_vec
#     return (emb[axis[1]] - emb[axis[0]])
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 395, in __getitem__
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# KeyError: "Key 'superescrito' not present"
# 2025-06-20 19:33:10 semaxis      ERROR    ('subyacente', 'superyacente') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis\semaxis.py", line 29, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis\core.py", line 19, in map_axis_to_vec
#     return (emb[axis[1]] - emb[axis[0]])
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 395, in __getitem__
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# KeyError: "Key 'superyacente' not present"
# 2025-06-20 19:33:10 semaxis      ERROR    ('subíndice', 'superescrito') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis\semaxis.py", line 29, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis\core.py", line 19, in map_axis_to_vec
#     return (emb[axis[1]] - emb[axis[0]])
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 395, in __getitem__
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# KeyError: "Key 'superescrito' not present"
# 2025-06-20 19:33:10 semaxis      ERROR    ('ungiculado', 'ungulado') axis is not included in embedding
# Traceback (most recent call last):
#   File "../frameaxis\semaxis.py", line 29, in _build_axes_on_embedding
#     mapped_axes[axis] = CoreUtil.map_axis_to_vec(self.embedding, axis)
#   File "../frameaxis\core.py", line 19, in map_axis_to_vec
#     return (emb[axis[1]] - emb[axis[0]])
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 395, in __getitem__
#     return self.get_vector(key_or_keys)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 438, in get_vector
#     index = self.get_index(key)
#   File "c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\gensim\models\keyedvectors.py", line 412, in get_index
#     raise KeyError(f"Key '{key}' not present")
# KeyError: "Key 'ungiculado' not present"

# %% [markdown]
# Guardamos el objeto para no cargarlo cada vez

# %%
import pickle 
#pickle.dump(frameaxis, open('frameaxis_object.p', 'wb'))
frameaxis = pickle.load(open('frameaxis_object.p', 'rb'))

# %% [markdown]
# ### Construcción de tabla con los bias por cada eje

# %%
COLUMNS = [str(c) for c in sorted(frameaxis.axes.keys()) if len(c) == 2]

def create_bias_table(table_path, col_to_process):
    with open(table_path, "w", encoding='utf-8') as bias_table:
        bias_table.write("{}\t{}\n".format(
            "uri", 
            "\t".join(COLUMNS)
        ))

        for loop_index, (row_index, row) in enumerate(news_df.iterrows()):
            if loop_index % (100) == 0: logger.info(loop_index)

            try:
                preprocessed_text = CoreUtil.preprocess(row[col_to_process])
                mean = frameaxis.compute_document_mean_with_tf([preprocessed_text], min_freq = 1)[0]
            except Exception as e:
                print(f"Error en loop index {loop_index}, fila {row_index}: {e}")
                continue

            bias_table.write("{}\t{}\n".format(
                str(row['uri']), 
                "\t".join([str(v) for v in mean])
            ))

# %%
create_bias_table(f"results/bias_table_body.tsv", "body")
create_bias_table(f"results/bias_table_gpt_summaries.tsv", "summary")
create_bias_table(f"results/bias_table_claude_summaries.tsv", "summary_claude")
create_bias_table(f"results/bias_table_gemini_summaries.tsv", "summary_gemini")
# Out:
# 2025-06-20 19:48:43 __main__     INFO     0
# c:\Users\fuent\AppData\Local\pypoetry\Cache\virtualenvs\frameaxis-nVQu9Ozg-py3.8\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# 2025-06-20 19:49:00 __main__     INFO     100
# 2025-06-20 19:49:12 __main__     INFO     200
# 2025-06-20 19:49:30 __main__     INFO     300
# 2025-06-20 19:49:43 __main__     INFO     400
# 2025-06-20 19:49:58 __main__     INFO     500
# 2025-06-20 19:50:10 __main__     INFO     600
# 2025-06-20 19:50:22 __main__     INFO     700
# 2025-06-20 19:50:32 __main__     INFO     800
# 2025-06-20 19:50:42 __main__     INFO     900
# 2025-06-20 19:50:59 __main__     INFO     1000
# 2025-06-20 19:51:08 __main__     INFO     1100
# 2025-06-20 19:51:15 __main__     INFO     1200
# 2025-06-20 19:51:28 __main__     INFO     1300
# 2025-06-20 19:51:42 __main__     INFO     1400
# 2025-06-20 19:51:58 __main__     INFO     0
# 2025-06-20 19:52:06 __main__     INFO     100
# 2025-06-20 19:52:13 __main__     INFO     200
# 2025-06-20 19:52:20 __main__     INFO     300
# 2025-06-20 19:52:26 __main__     INFO     400
# 2025-06-20 19:52:34 __main__     INFO     500
# 2025-06-20 19:52:41 __main__     INFO     600
# 2025-06-20 19:52:48 __main__     INFO     700
# 2025-06-20 19:52:54 __main__     INFO     800
# 2025-06-20 19:53:02 __main__     INFO     900
# 2025-06-20 19:53:09 __main__     INFO     1000
# 2025-06-20 19:53:16 __main__     INFO     1100
# 2025-06-20 19:53:22 __main__     INFO     1200
# 2025-06-20 19:53:28 __main__     INFO     1300
# 2025-06-20 19:53:36 __main__     INFO     1400
# 2025-06-20 19:53:44 __main__     INFO     0
# 2025-06-20 19:53:52 __main__     INFO     100
# 2025-06-20 19:54:01 __main__     INFO     200
# 2025-06-20 19:54:09 __main__     INFO     300
# 2025-06-20 19:54:17 __main__     INFO     400
# 2025-06-20 19:54:25 __main__     INFO     500
# 2025-06-20 19:54:32 __main__     INFO     600
# 2025-06-20 19:54:38 __main__     INFO     700
# 2025-06-20 19:54:44 __main__     INFO     800
# 2025-06-20 19:54:50 __main__     INFO     900
# 2025-06-20 19:54:58 __main__     INFO     1000
# 2025-06-20 19:55:04 __main__     INFO     1100
# 2025-06-20 19:55:10 __main__     INFO     1200
# 2025-06-20 19:55:16 __main__     INFO     1300
# 2025-06-20 19:55:23 __main__     INFO     1400
# 2025-06-20 19:55:29 __main__     INFO     0
# 2025-06-20 19:55:35 __main__     INFO     100
# 2025-06-20 19:55:40 __main__     INFO     200
# 2025-06-20 19:55:47 __main__     INFO     300
# 2025-06-20 19:55:53 __main__     INFO     400
# 2025-06-20 19:55:59 __main__     INFO     500
# 2025-06-20 19:56:05 __main__     INFO     600
# 2025-06-20 19:56:10 __main__     INFO     700
# 2025-06-20 19:56:16 __main__     INFO     800
# 2025-06-20 19:56:21 __main__     INFO     900
# 2025-06-20 19:56:27 __main__     INFO     1000
# 2025-06-20 19:56:33 __main__     INFO     1100
# 2025-06-20 19:56:38 __main__     INFO     1200
# 2025-06-20 19:56:43 __main__     INFO     1300
# 2025-06-20 19:56:50 __main__     INFO     1400

# %% [markdown]
# ### Calculo de intensity

# %%
import numpy as np

# %%
COLUMNS = [str(c) for c in sorted(frameaxis.axes.keys()) if len(c) == 2]

def create_intensity_table(table_path, model = None):
    if model:
        df_corpus = pd.read_csv(f"results/bias_table_{model}_summaries.tsv", sep="\t", dtype={'uri': str})
    else:
        df_corpus = pd.read_csv(f"results/bias_table_body.tsv", sep="\t", dtype={'uri': str})

    # para cada microframe promedia el bias a lo largo de los textos
    corpus_mean = np.mean(df_corpus.drop(
        columns=[c for c in df_corpus.columns if '(' not in c]).values, axis=0)
    
    if model:
        if model == 'gpt':
            col_to_process = 'summary'
        else:
            col_to_process = f'summary_{model}'
    else:
        col_to_process = 'body'

    with open(table_path, "w", encoding='utf-8') as intensity_table:
        intensity_table.write("{}\t{}\n".format(
            "uri",
            "\t".join(COLUMNS)
        ))
        for loop_index, (row_index, row) in enumerate(news_df.iterrows()):
            if loop_index % (100) == 0: logger.info(loop_index)

            try:
                preprocessed_text = CoreUtil.preprocess(row[col_to_process])
                sm = frameaxis.compute_document_second_moment_with_tf([preprocessed_text], corpus_mean, min_freq = 1)  
            except Exception as e:
                print(f"Error en loop index {loop_index}, fila {row_index}: {e}")
                continue

            intensity_table.write("{}\t{}\n".format(
                row['uri'],
                "\t".join([str(v) for v in sm[0]])
            ))

# %%
create_intensity_table(f"results/intensity_table_body.tsv")
create_intensity_table(f"results/intensity_table_gpt_summaries.tsv", "gpt")
create_intensity_table(f"results/intensity_table_claude_summaries.tsv", "claude")
create_intensity_table(f"results/intensity_table_gemini_summaries.tsv", "gemini")
# Out:
# 2025-06-22 14:44:00 __main__     INFO     0
# 2025-06-22 14:44:39 __main__     INFO     100
# 2025-06-22 14:45:16 __main__     INFO     200
# 2025-06-22 14:46:03 __main__     INFO     300
# 2025-06-22 14:46:43 __main__     INFO     400
# 2025-06-22 14:47:27 __main__     INFO     500
# 2025-06-22 14:48:02 __main__     INFO     600
# 2025-06-22 14:48:36 __main__     INFO     700
# 2025-06-22 14:49:02 __main__     INFO     800
# 2025-06-22 14:49:28 __main__     INFO     900
# 2025-06-22 14:50:18 __main__     INFO     1000
# 2025-06-22 14:50:47 __main__     INFO     1100
# 2025-06-22 14:51:01 __main__     INFO     1200
# 2025-06-22 14:51:12 __main__     INFO     1300
# 2025-06-22 14:51:24 __main__     INFO     1400
# 2025-06-22 14:51:38 __main__     INFO     0
# 2025-06-22 14:51:45 __main__     INFO     100
# 2025-06-22 14:51:52 __main__     INFO     200
# 2025-06-22 14:51:59 __main__     INFO     300
# 2025-06-22 14:52:06 __main__     INFO     400
# 2025-06-22 14:52:13 __main__     INFO     500
# 2025-06-22 14:52:20 __main__     INFO     600
# 2025-06-22 14:52:26 __main__     INFO     700
# 2025-06-22 14:52:34 __main__     INFO     800
# 2025-06-22 14:52:41 __main__     INFO     900
# 2025-06-22 14:52:48 __main__     INFO     1000
# 2025-06-22 14:52:54 __main__     INFO     1100
# 2025-06-22 14:52:59 __main__     INFO     1200
# 2025-06-22 14:53:06 __main__     INFO     1300
# 2025-06-22 14:53:13 __main__     INFO     1400
# 2025-06-22 14:53:20 __main__     INFO     0
# 2025-06-22 14:53:26 __main__     INFO     100
# 2025-06-22 14:53:33 __main__     INFO     200
# 2025-06-22 14:53:41 __main__     INFO     300
# 2025-06-22 14:53:47 __main__     INFO     400
# 2025-06-22 14:53:55 __main__     INFO     500
# 2025-06-22 14:54:01 __main__     INFO     600
# 2025-06-22 14:54:08 __main__     INFO     700
# 2025-06-22 14:54:16 __main__     INFO     800
# 2025-06-22 14:54:23 __main__     INFO     900
# 2025-06-22 14:54:31 __main__     INFO     1000
# 2025-06-22 14:54:37 __main__     INFO     1100
# 2025-06-22 14:54:44 __main__     INFO     1200
# 2025-06-22 14:54:50 __main__     INFO     1300
# 2025-06-22 14:54:57 __main__     INFO     1400
# 2025-06-22 14:55:05 __main__     INFO     0
# 2025-06-22 14:55:12 __main__     INFO     100
# 2025-06-22 14:55:19 __main__     INFO     200
# 2025-06-22 14:55:26 __main__     INFO     300
# 2025-06-22 14:55:33 __main__     INFO     400
# 2025-06-22 14:55:42 __main__     INFO     500
# 2025-06-22 14:55:48 __main__     INFO     600
# 2025-06-22 14:55:54 __main__     INFO     700
# 2025-06-22 14:55:59 __main__     INFO     800
# 2025-06-22 14:56:05 __main__     INFO     900
# 2025-06-22 14:56:12 __main__     INFO     1000
# 2025-06-22 14:56:18 __main__     INFO     1100
# 2025-06-22 14:56:23 __main__     INFO     1200
# 2025-06-22 14:56:29 __main__     INFO     1300
# 2025-06-22 14:56:35 __main__     INFO     1400
